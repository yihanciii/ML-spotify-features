# %%
import pandas as pd

df = pd.read_csv("df_pca.csv")

df.head()
# Out:
#    Week_End Week_Start_Fri               Week_Label  Weekly_Rank  \
# 0  2017/1/6     2016/12/31  2016-12-31 → 2017-01-06            1
# 1  2017/1/6     2016/12/31  2016-12-31 → 2017-01-06            2
# 2  2017/1/6     2016/12/31  2016-12-31 → 2017-01-06            3
# 3  2017/1/6     2016/12/31  2016-12-31 → 2017-01-06            4
# 4  2017/1/6     2016/12/31  2016-12-31 → 2017-01-06            5
#
#                        id                                              Title  \
# 0  5aAx2yezTd8zXrkmtKl66Z                                            Starboy
# 1  7BKLCZ1jbUBVqRi2FVlTVw                                             Closer
# 2  5knuzwU65gJK7IF5yJsuaW            Rockabye (feat. Sean Paul & Anne-Marie)
# 3  4pdPtRcBmOSQDlJ3Fk945m                                    Let Me Love You
# 4  3NdDpSvN911VPGivFlV5d0  I Don't Wan Live Forever (Fifty Shades Darker)...
#
#                 Artists_All  Weekly_Points  Streams  Days_Charted  ...  \
# ...

# %%
features = [
    "Danceability", "Energy", "Loudness",
    "Speechiness", "Acousticness",
    "Instrumentalness", "Valence"
]

table2 = df.groupby("Stage")[features].agg(["mean", "std"]).round(3)

table2
# Out:
#                     Danceability        Energy        Loudness         \
#                             mean    std   mean    std     mean    std
# Stage
# Stage 1 (2017-2019)        0.699  0.131  0.641  0.159   -6.023  2.324
# Stage 2 (2020-2022)        0.680  0.145  0.632  0.162   -6.212  2.404
# Stage 3 (2023-2025)        0.640  0.150  0.639  0.171   -6.674  3.636
#
#                     Speechiness        Acousticness        Instrumentalness  \
#                            mean    std         mean    std             mean
# Stage
# Stage 1 (2017-2019)       0.117  0.104        0.217  0.224            0.007
# Stage 2 (2020-2022)       0.104  0.096        0.259  0.257            0.010
# Stage 3 (2023-2025)       0.074  0.071        0.256  0.264            0.022
#
#                            Valence
#                        std    mean    std
# Stage
# Stage 1 (2017-2019)  0.050   0.495  0.217
# Stage 2 (2020-2022)  0.065   0.513  0.233
# Stage 3 (2023-2025)  0.108   0.508  0.238
